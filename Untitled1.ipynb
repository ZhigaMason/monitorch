# %%
from datasets import load_dataset

ds = load_dataset("zh-plus/tiny-imagenet")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# dataset_infos.json: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001-1359597a978bc4(…):   0%|          | 0.00/146M [00:00<?, ?B/s]
# data/valid-00000-of-00001-70d52db3c749a9(…):   0%|          | 0.00/14.6M [00:00<?, ?B/s]
# ...
# Generating valid split:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 100000
#     })
#     valid: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
ds['train']
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 100000
# })

# %%
img, label = next(iter(ds['train']))
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=64x64>,
#  'label': 0}

# %%
ds.with_format('torch')['train'][0]
# Out:
# {'image': tensor([[[255, 255, 249,  ..., 208, 209, 127],
#           [255, 254, 246,  ..., 205, 202, 123],
#           [255, 255, 255,  ..., 207, 202, 120],
#           ...,
#           [ 95,  93,  93,  ...,  85,  78,  94],
#           [ 89,  89,  89,  ...,  86,  77,  87],
#           [ 91,  91,  93,  ...,  96,  77,  72]],
#
#          [[136, 138, 146,  ..., 237, 241, 163],
#           [126, 128, 137,  ..., 231, 234, 159],
#           [126, 129, 135,  ..., 233, 234, 155],
#           ...,
#           [122, 119, 116,  ...,  74,  67,  83],
#           [117, 115, 112,  ...,  75,  66,  76],
#           [119, 119, 116,  ...,  85,  66,  61]],
#
#          [[193, 192, 199,  ..., 235, 240, 161],
#           [189, 189, 194,  ..., 230, 231, 155],
#           [201, 201, 203,  ..., 230, 229, 149],
#           ...,
#           [ 71,  71,  70,  ...,  56,  49,  65],
#           [ 66,  67,  66,  ...,  57,  48,  58],
#           [ 68,  70,  70,  ...,  67,  48,  43]]], dtype=torch.uint8),
# ...

# %%
import torch
from torch.utils.data import DataLoader

# %%
dl = DataLoader(ds.with_format('torch')['train'], batch_size=32)
dl

# %%
for d in dl:
    img = d['image']
    label = d['label']
    print(img, label)
    break
# Out:
# tensor([[[[255, 255, 249,  ..., 208, 209, 127],
#           [255, 254, 246,  ..., 205, 202, 123],
#           [255, 255, 255,  ..., 207, 202, 120],
#           ...,
#           [ 95,  93,  93,  ...,  85,  78,  94],
#           [ 89,  89,  89,  ...,  86,  77,  87],
#           [ 91,  91,  93,  ...,  96,  77,  72]],
#
#          [[136, 138, 146,  ..., 237, 241, 163],
#           [126, 128, 137,  ..., 231, 234, 159],
#           [126, 129, 135,  ..., 233, 234, 155],
#           ...,
#           [122, 119, 116,  ...,  74,  67,  83],
#           [117, 115, 112,  ...,  75,  66,  76],
#           [119, 119, 116,  ...,  85,  66,  61]],
#
#          [[193, 192, 199,  ..., 235, 240, 161],
#           [189, 189, 194,  ..., 230, 231, 155],
#           [201, 201, 203,  ..., 230, 229, 149],
#           ...,
#           [ 71,  71,  70,  ...,  56,  49,  65],
#           [ 66,  67,  66,  ...,  57,  48,  58],
#           [ 68,  70,  70,  ...,  67,  48,  43]]],
#
#
# ...

# %%
next(iter(dl))
# Out:
# {'image': tensor([[[[255, 255, 249,  ..., 208, 209, 127],
#            [255, 254, 246,  ..., 205, 202, 123],
#            [255, 255, 255,  ..., 207, 202, 120],
#            ...,
#            [ 95,  93,  93,  ...,  85,  78,  94],
#            [ 89,  89,  89,  ...,  86,  77,  87],
#            [ 91,  91,  93,  ...,  96,  77,  72]],
#
#           [[136, 138, 146,  ..., 237, 241, 163],
#            [126, 128, 137,  ..., 231, 234, 159],
#            [126, 129, 135,  ..., 233, 234, 155],
#            ...,
#            [122, 119, 116,  ...,  74,  67,  83],
#            [117, 115, 112,  ...,  75,  66,  76],
#            [119, 119, 116,  ...,  85,  66,  61]],
#
#           [[193, 192, 199,  ..., 235, 240, 161],
#            [189, 189, 194,  ..., 230, 231, 155],
#            [201, 201, 203,  ..., 230, 229, 149],
#            ...,
#            [ 71,  71,  70,  ...,  56,  49,  65],
#            [ 66,  67,  66,  ...,  57,  48,  58],
#            [ 68,  70,  70,  ...,  67,  48,  43]]],
#
#
# ...
